# %%
import numpy as np
# %matplotlib notebook
from matplotlib import pyplot as plt

# %%
plt.figure
ax = plt.imshow(np.random.random((600, 800)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_data(np.random.random((800, 600)))
